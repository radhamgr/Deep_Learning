# %%
import numpy as np
xAll = np.array(([2,9],[1,5],[3,6],[5,10]),dtype=float)
y = np.array(([92],[86],[89]),dtype=float)
 
#scale
xAll = xAll/np.amax(xAll,axis=0)
y = y/100 # s
# split data
X = np.split(xAll, [3])[0] # training data
xPredicted = np.split(xAll, [3])[1] # testing data

# %%
class Neural_Network(object):
    def __init__(self):
        #parameters
        self.inputSize = 2
        self.outputSize = 1
        self.hiddenSize = 3
      
    # weights
        self.w1 = np.random.randn(self.inputSize,self.hiddenSize)
        self.w2 = np.random.randn(self.hiddenSize,self.outputSize)
    
    #actication function
    def sigmoid(self,s):
        return 1/(1+np.exp(-s))
    
    def forward(self,X):
        #forward propagation through our network
        self.z = np.dot(X,self.w1)
        self.z2 = self.sigmoid(self.z)
        self.z3 = np.dot(self.z2,self.w2)
        o = self.sigmoid(self.z3)
        return o
    
    def sigmoidPrime(self, s):
        #derivative of sigmoid
        return s * (1 - s)
    
    def back_propagation(self,X,y,o):
        self.o_error = y-o
        self.o_delta = self.o_error*self.sigmoidPrime(o)
        
        self.z2_error = self.o_delta*(self.w2.T)
        self.z2_delta = self.z2_error*self.sigmoidPrime(self.z2)
            
        self.w1 += X.T.dot(self.z2_delta)
        self.w2 += self.z2.T.dot(self.o_delta)
        
    def train (self, X, y):
        o = self.forward(X)
        self.back_propagation(X, y, o)

# %%
NN = Neural_Network()

#defining our output
o = NN.forward(X)

print("Predicted Output: \n" + str(o))
print("Actual Output: \n" + str(y))
# Out:
# Predicted Output:
# [[0.30847503]
#  [0.25182251]
#  [0.30539933]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]

# %%
NN = Neural_Network()
for i in range(1000): # trains the NN 1,000 times
    print("Input: \n" + str(X))
    print("Actual Output: \n" + str(y))
    print("Predicted Output: \n" + str(NN.forward(X)))
    print("Loss: \n" + str(np.mean(np.square(y - NN.forward(X)))))# mean sum squared loss
    print("\n")
    NN.train(X, y)
# Out:
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.52437959]
#  [0.48336156]
#  [0.51191229]]
# Loss:
# 0.14710744758821867
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.56724518]
#  [0.52751084]
#  [0.55334471]]
# Loss:
# 0.11610726397274478
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.60493956]
#  [0.56640803]
#  [0.58983948]]
# Loss:
# 0.091851886451207
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.63772596]
#  [0.60017355]
#  [0.62162918]]
# Loss:
# 0.07307043731579527
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.66606088]
#  [0.62924755]
#  [0.64914745]]
# Loss:
# 0.058580572607025864
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.6904812 ]
#  [0.65420489]
#  [0.67290984]]
# Loss:
# 0.04738621559255233
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.71152946]
#  [0.67563887]
#  [0.69343728]]
# Loss:
# 0.03869529842142378
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.72971047]
#  [0.69409983]
#  [0.71121324]]
# Loss:
# 0.0318992255798096
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.74547097]
#  [0.71006949]
#  [0.72666454]]
# Loss:
# 0.026539337585857414
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.75919412]
#  [0.72395592]
#  [0.74015667]]
# Loss:
# 0.022273182086207988
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.77120242]
#  [0.73609838]
#  [0.75199694]]
# Loss:
# 0.018845725317851475
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.78176427]
#  [0.74677627]
#  [0.76244114]]
# Loss:
# 0.01606666473198312
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.79110186]
#  [0.75621877]
#  [0.77170109]]
# Loss:
# 0.013793302289337749
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.79939878]
#  [0.76461381]
#  [0.77995201]]
# Loss:
# 0.01191791272701456
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.80680685]
#  [0.7721158 ]
#  [0.787339  ]]
# Loss:
# 0.010358533937998437
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8134519 ]
#  [0.7788521 ]
#  [0.79398249]]
# Loss:
# 0.009052280618010639
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.81943858]
#  [0.78492817]
#  [0.79998286]]
# Loss:
# 0.00795048758987254
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.82485432]
#  [0.79043185]
#  [0.8054241 ]]
# Loss:
# 0.007015169830583075
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.82977246]
#  [0.79543663]
#  [0.81037684]]
# Loss:
# 0.0062164282492403675
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83425484]
#  [0.80000436]
#  [0.81490074]]
# Loss:
# 0.005530535959070603
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83835386]
#  [0.80418735]
#  [0.81904647]]
# Loss:
# 0.004938516193381572
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84211411]
#  [0.80803011]
#  [0.82285724]]
# Loss:
# 0.004425077418651148
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84557376]
#  [0.81157068]
#  [0.8263701 ]]
# Loss:
# 0.00397780966532997
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84876559]
#  [0.81484174]
#  [0.82961698]]
# Loss:
# 0.0035865732449135226
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85171791]
#  [0.8178715 ]
#  [0.83262547]]
# Loss:
# 0.0032430302075548163
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85445528]
#  [0.82068444]
#  [0.83541956]]
# Loss:
# 0.002940282500744018
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85699907]
#  [0.82330187]
#  [0.83802018]]
# Loss:
# 0.0026725904862732754
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85936796]
#  [0.82574241]
#  [0.84044568]]
# Loss:
# 0.0024351524233169586
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86157836]
#  [0.82802245]
#  [0.84271216]]
# Loss:
# 0.0022239305394117846
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86364471]
#  [0.8301564 ]
#  [0.84483386]]
# Loss:
# 0.002035512952262964
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86557978]
#  [0.83215705]
#  [0.84682339]]
# Loss:
# 0.0018670033676511757
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8673949 ]
#  [0.83403571]
#  [0.84869193]]
# Loss:
# 0.0017159324388378177
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86910015]
#  [0.83580247]
#  [0.85044948]]
# Loss:
# 0.001580186125904065
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87070453]
#  [0.83746637]
#  [0.85210495]]
# Loss:
# 0.001457947477903808
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87221609]
#  [0.83903548]
#  [0.85366635]]
# Loss:
# 0.0013476490754457963
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87364206]
#  [0.84051705]
#  [0.85514088]]
# Loss:
# 0.0012479339874005722
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87498895]
#  [0.84191765]
#  [0.85653503]]
# Loss:
# 0.0011576235642336088
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87626263]
#  [0.84324317]
#  [0.85785466]]
# Loss:
# 0.0010756907493907344
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87746841]
#  [0.84449897]
#  [0.85910508]]
# Loss:
# 0.00100123786659275
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87861113]
#  [0.84568993]
#  [0.86029113]]
# Loss:
# 0.0009334780550156124
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87969514]
#  [0.84682045]
#  [0.86141719]]
# Loss:
# 0.0008717196911086411
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88072445]
#  [0.84789458]
#  [0.86248728]]
# Loss:
# 0.0008153532663991646
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8817027 ]
#  [0.848916  ]
#  [0.86350505]]
# Loss:
# 0.0007638402934272479
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88263321]
#  [0.84988808]
#  [0.86447386]]
# Loss:
# 0.0007167038932700897
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88351904]
#  [0.85081394]
#  [0.86539679]]
# Loss:
# 0.0006735207827505765
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88436298]
#  [0.8516964 ]
#  [0.86627667]]
# Loss:
# 0.0006339144310397307
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88516762]
#  [0.8525381 ]
#  [0.8671161 ]]
# Loss:
# 0.0005975491967646751
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88593532]
#  [0.85334145]
#  [0.86791749]]
# Loss:
# 0.0005641252900883513
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88666828]
#  [0.85410868]
#  [0.86868305]]
# Loss:
# 0.0005333744312095695
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88736853]
#  [0.85484185]
#  [0.86941484]]
# Loss:
# 0.000505056098648607
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88803792]
#  [0.8555429 ]
#  [0.87011477]]
# Loss:
# 0.00047895427855406016
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8886782 ]
#  [0.85621358]
#  [0.87078459]]
# Loss:
# 0.00045487464089296524
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88929099]
#  [0.85685555]
#  [0.87142595]]
# Loss:
# 0.000432642080401056
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88987777]
#  [0.85747035]
#  [0.87204038]]
# Loss:
# 0.0004120985700737621
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89043995]
#  [0.85805941]
#  [0.8726293 ]]
# Loss:
# 0.0003931012831703441
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89097882]
#  [0.85862407]
#  [0.87319403]]
# Loss:
# 0.00037552094650119525
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89149559]
#  [0.85916556]
#  [0.87373582]]
# Loss:
# 0.0003592403934272277
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8919914 ]
#  [0.85968507]
#  [0.87425583]]
# Loss:
# 0.00034415328972539166
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8924673 ]
#  [0.86018367]
#  [0.87475514]]
# Loss:
# 0.00033016300943195426
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89292429]
#  [0.8606624 ]
#  [0.87523477]]
# Loss:
# 0.0003171816410988156
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8933633 ]
#  [0.86112221]
#  [0.87569567]]
# Loss:
# 0.0003051291076979551
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89378519]
#  [0.861564  ]
#  [0.87613873]]
# Loss:
# 0.00029393238577321893
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89419079]
#  [0.86198863]
#  [0.87656481]]
# Loss:
# 0.000283524811440826
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89458087]
#  [0.8623969 ]
#  [0.87697468]]
# Loss:
# 0.00027384546253934736
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89495614]
#  [0.86278954]
#  [0.87736911]]
# Loss:
# 0.0002648386076763238
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8953173 ]
#  [0.86316727]
#  [0.87774878]]
# Loss:
# 0.00025645321415224007
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89566498]
#  [0.86353077]
#  [0.87811437]]
# Loss:
# 0.0002486425077976129
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8959998 ]
#  [0.86388065]
#  [0.8784665 ]]
# Loss:
# 0.00024136357866273955
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89632232]
#  [0.86421752]
#  [0.87880576]]
# Loss:
# 0.0002345770272761266
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89663308]
#  [0.86454194]
#  [0.87913271]]
# Loss:
# 0.0002282466468556647
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8969326 ]
#  [0.86485444]
#  [0.87944789]]
# Loss:
# 0.00022233913743299584
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89722137]
#  [0.86515554]
#  [0.87975179]]
# Loss:
# 0.000216823848349386
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89749983]
#  [0.8654457 ]
#  [0.88004488]]
# Loss:
# 0.0002116725460126549
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89776843]
#  [0.86572539]
#  [0.88032763]]
# Loss:
# 0.0002068592041788736
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89802757]
#  [0.86599504]
#  [0.88060046]]
# Loss:
# 0.00020235981434745315
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89827766]
#  [0.86625505]
#  [0.88086377]]
# Loss:
# 0.00019815221414156486
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89851905]
#  [0.86650581]
#  [0.88111794]]
# Loss:
# 0.00019421593179259794
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8987521 ]
#  [0.86674771]
#  [0.88136336]]
# Loss:
# 0.00019053204506315293
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89897716]
#  [0.86698108]
#  [0.88160036]]
# Loss:
# 0.00018708305313185774
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89919453]
#  [0.86720626]
#  [0.88182929]]
# Loss:
# 0.00018385276012891
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89940453]
#  [0.86742359]
#  [0.88205045]]
# Loss:
# 0.00018082616915643165
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89960744]
#  [0.86763335]
#  [0.88226414]]
# Loss:
# 0.00017798938575564916
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89980353]
#  [0.86783584]
#  [0.88247067]]
# Loss:
# 0.00017532952989542645
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89999308]
#  [0.86803134]
#  [0.88267029]]
# Loss:
# 0.00017283465565592326
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90017633]
#  [0.86822011]
#  [0.88286328]]
# Loss:
# 0.00017049367786892207
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90035352]
#  [0.86840241]
#  [0.88304988]]
# Loss:
# 0.00016829630505379154
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90052488]
#  [0.86857847]
#  [0.88323033]]
# Loss:
# 0.0001662329780569564
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90069063]
#  [0.86874853]
#  [0.88340487]]
# Loss:
# 0.00016429481386346474
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90085098]
#  [0.86891282]
#  [0.8835737 ]]
# Loss:
# 0.000162473554103504
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90100613]
#  [0.86907153]
#  [0.88373705]]
# Loss:
# 0.0001607615178247748
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90115626]
#  [0.86922488]
#  [0.8838951 ]]
# Loss:
# 0.00015915155814448417
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90130157]
#  [0.86937306]
#  [0.88404805]]
# Loss:
# 0.00015763702243291593
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90144223]
#  [0.86951624]
#  [0.88419609]]
# Loss:
# 0.00015621171571461484
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9015784 ]
#  [0.86965463]
#  [0.88433939]]
# Loss:
# 0.00015486986700369857
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90171025]
#  [0.86978837]
#  [0.88447812]]
# Loss:
# 0.00015360609831700081
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90183793]
#  [0.86991764]
#  [0.88461244]]
# Loss:
# 0.00015241539613322695
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90196158]
#  [0.87004259]
#  [0.8847425 ]]
# Loss:
# 0.00015129308508813428
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90208136]
#  [0.87016337]
#  [0.88486847]]
# Loss:
# 0.00015023480371534863
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90219739]
#  [0.87028014]
#  [0.88499046]]
# Loss:
# 0.00014923648206018291
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90230981]
#  [0.87039302]
#  [0.88510864]]
# Loss:
# 0.00014829432100953223
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90241874]
#  [0.87050215]
#  [0.88522312]]
# Loss:
# 0.00014740477319534742
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9025243 ]
#  [0.87060766]
#  [0.88533404]]
# Loss:
# 0.0001465645253419755
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90262661]
#  [0.87070967]
#  [0.88544151]]
# Loss:
# 0.00014577048193926417
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90272578]
#  [0.87080831]
#  [0.88554565]]
# Loss:
# 0.00014501975013388334
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90282192]
#  [0.87090368]
#  [0.88564659]]
# Loss:
# 0.00014430962574070861
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90291512]
#  [0.87099589]
#  [0.88574441]]
# Loss:
# 0.00014363758028470086
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9030055 ]
#  [0.87108506]
#  [0.88583923]]
# Loss:
# 0.0001430012489915273
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90309313]
#  [0.87117128]
#  [0.88593115]]
# Loss:
# 0.00014239841965213844
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90317812]
#  [0.87125465]
#  [0.88602027]]
# Loss:
# 0.00014182702229288444
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90326055]
#  [0.87133526]
#  [0.88610667]]
# Loss:
# 0.00014128511958862538
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90334051]
#  [0.87141322]
#  [0.88619045]]
# Loss:
# 0.00014077089796143554
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90341808]
#  [0.87148859]
#  [0.8862717 ]]
# Loss:
# 0.0001402826593123818
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90349334]
#  [0.87156147]
#  [0.88635049]]
# Loss:
# 0.00013981881333811482
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90356636]
#  [0.87163194]
#  [0.88642691]]
# Loss:
# 0.0001393778703880537
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90363722]
#  [0.87170008]
#  [0.88650103]]
# Loss:
# 0.00013895843482149086
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90370598]
#  [0.87176596]
#  [0.88657293]]
# Loss:
# 0.00013855919882727521
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90377272]
#  [0.87182965]
#  [0.88664268]]
# Loss:
# 0.00013817893667169122
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90383751]
#  [0.87189124]
#  [0.88671035]]
# Loss:
# 0.00013781649934298346
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90390039]
#  [0.87195077]
#  [0.88677601]]
# Loss:
# 0.0001374708095633187
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90396144]
#  [0.87200833]
#  [0.88683972]]
# Loss:
# 0.00013714085714148548
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90402072]
#  [0.87206397]
#  [0.88690155]]
# Loss:
# 0.00013682569464152082
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90407828]
#  [0.87211775]
#  [0.88696155]]
# Loss:
# 0.00013652443334454382
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90413417]
#  [0.87216974]
#  [0.88701978]]
# Loss:
# 0.00013623623948268607
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90418845]
#  [0.87221998]
#  [0.8870763 ]]
# Loss:
# 0.00013596033072578665
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424118]
#  [0.87226854]
#  [0.88713116]]
# Loss:
# 0.00013569597290281083
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90429239]
#  [0.87231547]
#  [0.88718441]]
# Loss:
# 0.00013544247694152265
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90434214]
#  [0.87236082]
#  [0.88723611]]
# Loss:
# 0.00013519919601098087
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90439047]
#  [0.87240464]
#  [0.8872863 ]]
# Loss:
# 0.0001349655228527306
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90443743]
#  [0.87244697]
#  [0.88733504]]
# Loss:
# 0.00013474088728757385
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90448306]
#  [0.87248787]
#  [0.88738236]]
# Loss:
# 0.00013452475388569773
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9045274 ]
#  [0.87252737]
#  [0.88742831]]
# Loss:
# 0.00013431661978898865
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9045705 ]
#  [0.87256553]
#  [0.88747293]]
# Loss:
# 0.00013411601267501708
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90461239]
#  [0.87260238]
#  [0.88751627]]
# Loss:
# 0.0001339224888530796
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9046531 ]
#  [0.87263796]
#  [0.88755836]]
# Loss:
# 0.00013373563148325277
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90469268]
#  [0.87267231]
#  [0.88759925]]
# Loss:
# 0.00013355504891020148
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90473116]
#  [0.87270548]
#  [0.88763896]]
# Loss:
# 0.0001333803731039694
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90476858]
#  [0.8727375 ]
#  [0.88767754]]
# Loss:
# 0.00013321125820054498
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90480496]
#  [0.87276839]
#  [0.88771502]]
# Loss:
# 0.0001330473791355957
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90484034]
#  [0.87279821]
#  [0.88775144]]
# Loss:
# 0.00013288843036512248
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90487476]
#  [0.87282697]
#  [0.88778682]]
# Loss:
# 0.0001327341246672559
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90490823]
#  [0.87285472]
#  [0.88782121]]
# Loss:
# 0.00013258419201987728
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90494079]
#  [0.87288148]
#  [0.88785462]]
# Loss:
# 0.00013243837854902822
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90497246]
#  [0.87290729]
#  [0.88788709]]
# Loss:
# 0.000132296445543503
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90500328]
#  [0.87293217]
#  [0.88791865]]
# Loss:
# 0.00013215816853125902
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90503327]
#  [0.87295614]
#  [0.88794932]]
# Loss:
# 0.0001320233364136522
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90506245]
#  [0.87297925]
#  [0.88797914]]
# Loss:
# 0.0001318917506537157
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90509085]
#  [0.87300152]
#  [0.88800813]]
# Loss:
# 0.00013176322451500952
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9051185 ]
#  [0.87302296]
#  [0.8880363 ]]
# Loss:
# 0.00013163758234775402
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90514541]
#  [0.87304361]
#  [0.8880637 ]]
# Loss:
# 0.0001315146589192342
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90517161]
#  [0.87306349]
#  [0.88809034]]
# Loss:
# 0.0001313942987856086
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90519711]
#  [0.87308262]
#  [0.88811624]]
# Loss:
# 0.0001312763557025087
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90522195]
#  [0.87310103]
#  [0.88814143]]
# Loss:
# 0.00013116069207191715
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90524614]
#  [0.87311874]
#  [0.88816593]]
# Loss:
# 0.0001310471784230725
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9052697 ]
#  [0.87313576]
#  [0.88818975]]
# Loss:
# 0.00013093569292518207
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90529264]
#  [0.87315213]
#  [0.88821293]]
# Loss:
# 0.0001308261209299944
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.905315  ]
#  [0.87316785]
#  [0.88823547]]
# Loss:
# 0.00013071835454230715
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90533678]
#  [0.87318295]
#  [0.8882574 ]]
# Loss:
# 0.0001306122922166691
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.905358  ]
#  [0.87319745]
#  [0.88827874]]
# Loss:
# 0.00013050783837864093
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90537868]
#  [0.87321136]
#  [0.8882995 ]]
# Loss:
# 0.00013040490306906772
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90539884]
#  [0.87322471]
#  [0.8883197 ]]
# Loss:
# 0.00013030340160994052
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90541849]
#  [0.8732375 ]
#  [0.88833936]]
# Loss:
# 0.0001302032542904783
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90543764]
#  [0.87324977]
#  [0.88835849]]
# Loss:
# 0.00013010438607221264
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90545632]
#  [0.87326151]
#  [0.88837712]]
# Loss:
# 0.0001300067263118668
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90547453]
#  [0.87327275]
#  [0.88839524]]
# Loss:
# 0.00012991020850094102
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90549228]
#  [0.87328351]
#  [0.88841289]]
# Loss:
# 0.0001298147700209666
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90550961]
#  [0.87329379]
#  [0.88843007]]
# Loss:
# 0.00012972035191348828
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9055265 ]
#  [0.87330361]
#  [0.88844679]]
# Loss:
# 0.00012962689866382837
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90554299]
#  [0.87331299]
#  [0.88846308]]
# Loss:
# 0.00012953435799783333
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90555907]
#  [0.87332194]
#  [0.88847894]]
# Loss:
# 0.00012944268069077156
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90557477]
#  [0.87333047]
#  [0.88849439]]
# Loss:
# 0.00012935182038766163
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90559009]
#  [0.87333859]
#  [0.88850944]]
# Loss:
# 0.00012926173343431988
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90560505]
#  [0.87334632]
#  [0.88852409]]
# Loss:
# 0.00012917237871850216
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90561965]
#  [0.87335366]
#  [0.88853837]]
# Loss:
# 0.00012908371752048993
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9056339 ]
#  [0.87336064]
#  [0.88855229]]
# Loss:
# 0.0001289957133725609
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90564783]
#  [0.87336725]
#  [0.88856584]]
# Loss:
# 0.0001289083319268349
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90566143]
#  [0.87337351]
#  [0.88857905]]
# Loss:
# 0.0001288215408309425
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90567471]
#  [0.87337944]
#  [0.88859193]]
# Loss:
# 0.0001287353096110702
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90568769]
#  [0.87338504]
#  [0.88860448]]
# Loss:
# 0.00012864960956194402
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90570038]
#  [0.87339032]
#  [0.88861671]]
# Loss:
# 0.00012856441364331595
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90571277]
#  [0.87339529]
#  [0.88862864]]
# Loss:
# 0.0001284796963825657
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90572489]
#  [0.87339995]
#  [0.88864027]]
# Loss:
# 0.0001283954337830663
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90573674]
#  [0.87340433]
#  [0.88865162]]
# Loss:
# 0.0001283116032379508
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90574832]
#  [0.87340843]
#  [0.88866268]]
# Loss:
# 0.0001282281834489623
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90575965]
#  [0.87341225]
#  [0.88867347]]
# Loss:
# 0.00012814515435009146
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90577074]
#  [0.8734158 ]
#  [0.88868399]]
# Loss:
# 0.00012806249703569965
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90578158]
#  [0.8734191 ]
#  [0.88869426]]
# Loss:
# 0.00012798019369287384
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90579219]
#  [0.87342214]
#  [0.88870429]]
# Loss:
# 0.0001278982275377588
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90580257]
#  [0.87342494]
#  [0.88871406]]
# Loss:
# 0.0001278165827556201
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90581273]
#  [0.87342751]
#  [0.88872361]]
# Loss:
# 0.00012773524444444548
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90582268]
#  [0.87342985]
#  [0.88873293]]
# Loss:
# 0.0001276541985618169
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90583242]
#  [0.87343196]
#  [0.88874202]]
# Loss:
# 0.00012757343187493205
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90584196]
#  [0.87343386]
#  [0.88875091]]
# Loss:
# 0.00012749293191352797
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90585131]
#  [0.87343555]
#  [0.88875958]]
# Loss:
# 0.00012741268692557632
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90586047]
#  [0.87343704]
#  [0.88876805]]
# Loss:
# 0.00012733268583555262
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90586944]
#  [0.87343833]
#  [0.88877633]]
# Loss:
# 0.00012725291820516626
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90587823]
#  [0.87343943]
#  [0.88878442]]
# Loss:
# 0.0001271733741963609
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90588686]
#  [0.87344034]
#  [0.88879232]]
# Loss:
# 0.00012709404453648763
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90589531]
#  [0.87344108]
#  [0.88880004]]
# Loss:
# 0.0001270149204855188
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9059036 ]
#  [0.87344164]
#  [0.88880759]]
# Loss:
# 0.00012693599380515154
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90591173]
#  [0.87344203]
#  [0.88881496]]
# Loss:
# 0.0001268572567297213
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90591971]
#  [0.87344225]
#  [0.88882218]]
# Loss:
# 0.00012677870193883393
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90592753]
#  [0.87344232]
#  [0.88882923]]
# Loss:
# 0.00012670032253154508
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90593522]
#  [0.87344223]
#  [0.88883613]]
# Loss:
# 0.00012662211200208435
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90594276]
#  [0.873442  ]
#  [0.88884288]]
# Loss:
# 0.00012654406421696324
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90595016]
#  [0.87344161]
#  [0.88884949]]
# Loss:
# 0.00012646617339343518
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90595744]
#  [0.87344109]
#  [0.88885595]]
# Loss:
# 0.00012638843407919412
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90596458]
#  [0.87344043]
#  [0.88886227]]
# Loss:
# 0.00012631084113325474
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9059716 ]
#  [0.87343963]
#  [0.88886846]]
# Loss:
# 0.00012623338970794312
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90597849]
#  [0.87343871]
#  [0.88887452]]
# Loss:
# 0.00012615607523194206
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90598527]
#  [0.87343766]
#  [0.88888046]]
# Loss:
# 0.00012607889339430963
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90599194]
#  [0.87343649]
#  [0.88888627]]
# Loss:
# 0.00012600184012942768
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90599849]
#  [0.8734352 ]
#  [0.88889197]]
# Loss:
# 0.00012592491160281713
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90600493]
#  [0.8734338 ]
#  [0.88889755]]
# Loss:
# 0.00012584810419780147
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90601127]
#  [0.87343229]
#  [0.88890301]]
# Loss:
# 0.00012577141450289655
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90601751]
#  [0.87343067]
#  [0.88890837]]
# Loss:
# 0.0001256948392999872
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90602365]
#  [0.87342895]
#  [0.88891362]]
# Loss:
# 0.00012561837555313525
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90602969]
#  [0.87342712]
#  [0.88891877]]
# Loss:
# 0.0001255420203980776
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90603564]
#  [0.8734252 ]
#  [0.88892383]]
# Loss:
# 0.00012546577113230458
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9060415 ]
#  [0.87342318]
#  [0.88892878]]
# Loss:
# 0.00012538962520572912
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90604727]
#  [0.87342107]
#  [0.88893364]]
# Loss:
# 0.00012531358021188458
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90605296]
#  [0.87341887]
#  [0.88893841]]
# Loss:
# 0.00012523763387963915
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90605856]
#  [0.87341658]
#  [0.88894309]]
# Loss:
# 0.00012516178406538888
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90606409]
#  [0.87341421]
#  [0.88894769]]
# Loss:
# 0.00012508602874569864
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90606953]
#  [0.87341176]
#  [0.8889522 ]]
# Loss:
# 0.00012501036601036196
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9060749 ]
#  [0.87340922]
#  [0.88895663]]
# Loss:
# 0.00012493479405588866
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90608019]
#  [0.87340661]
#  [0.88896098]]
# Loss:
# 0.0001248593111793237
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90608541]
#  [0.87340393]
#  [0.88896525]]
# Loss:
# 0.00012478391577248288
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90609057]
#  [0.87340117]
#  [0.88896946]]
# Loss:
# 0.0001247086063164529
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90609565]
#  [0.87339835]
#  [0.88897359]]
# Loss:
# 0.000124633381376474
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90610067]
#  [0.87339545]
#  [0.88897764]]
# Loss:
# 0.0001245582395970661
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90610563]
#  [0.87339249]
#  [0.88898164]]
# Loss:
# 0.00012448317969747624
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90611052]
#  [0.87338947]
#  [0.88898556]]
# Loss:
# 0.00012440820046735502
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90611536]
#  [0.87338639]
#  [0.88898942]]
# Loss:
# 0.00012433330076271464
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90612013]
#  [0.87338324]
#  [0.88899322]]
# Loss:
# 0.00012425847950209084
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90612485]
#  [0.87338004]
#  [0.88899696]]
# Loss:
# 0.00012418373566294887
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90612952]
#  [0.87337678]
#  [0.88900064]]
# Loss:
# 0.0001241090682782833
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90613413]
#  [0.87337346]
#  [0.88900426]]
# Loss:
# 0.00012403447643341827
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90613868]
#  [0.87337009]
#  [0.88900783]]
# Loss:
# 0.00012395995926299812
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90614319]
#  [0.87336667]
#  [0.88901134]]
# Loss:
# 0.00012388551594813544
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90614765]
#  [0.8733632 ]
#  [0.8890148 ]]
# Loss:
# 0.00012381114571374783
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90615206]
#  [0.87335969]
#  [0.88901821]]
# Loss:
# 0.0001237368478260185
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90615643]
#  [0.87335612]
#  [0.88902157]]
# Loss:
# 0.0001236626215900365
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90616075]
#  [0.87335251]
#  [0.88902489]]
# Loss:
# 0.00012358846634754256
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90616502]
#  [0.87334886]
#  [0.88902815]]
# Loss:
# 0.00012351438147482197
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90616926]
#  [0.87334516]
#  [0.88903137]]
# Loss:
# 0.00012344036638071984
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90617345]
#  [0.87334143]
#  [0.88903455]]
# Loss:
# 0.0001233664205047613
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9061776 ]
#  [0.87333765]
#  [0.88903768]]
# Loss:
# 0.0001232925433153861
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90618171]
#  [0.87333383]
#  [0.88904078]]
# Loss:
# 0.00012321873430828152
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90618579]
#  [0.87332998]
#  [0.88904383]]
# Loss:
# 0.0001231449930048204
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90618983]
#  [0.87332609]
#  [0.88904684]]
# Loss:
# 0.00012307131895057365
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90619383]
#  [0.87332216]
#  [0.88904982]]
# Loss:
# 0.0001229977117139268
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9061978 ]
#  [0.8733182 ]
#  [0.88905276]]
# Loss:
# 0.000122924170884755
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90620173]
#  [0.87331421]
#  [0.88905566]]
# Loss:
# 0.00012285069607320147
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90620564]
#  [0.87331019]
#  [0.88905853]]
# Loss:
# 0.0001227772869084893
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90620951]
#  [0.87330613]
#  [0.88906136]]
# Loss:
# 0.00012270394303785288
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90621335]
#  [0.87330204]
#  [0.88906416]]
# Loss:
# 0.00012263066412547137
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90621716]
#  [0.87329793]
#  [0.88906693]]
# Loss:
# 0.00012255744985151986
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90622094]
#  [0.87329379]
#  [0.88906967]]
# Loss:
# 0.00012248429991122518
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90622469]
#  [0.87328962]
#  [0.88907238]]
# Loss:
# 0.0001224112140140222
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90622841]
#  [0.87328542]
#  [0.88907505]]
# Loss:
# 0.00012233819188271942
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90623211]
#  [0.8732812 ]
#  [0.8890777 ]]
# Loss:
# 0.0001222652332527432
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90623578]
#  [0.87327695]
#  [0.88908033]]
# Loss:
# 0.0001221923378714009
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90623943]
#  [0.87327268]
#  [0.88908292]]
# Loss:
# 0.00012211950549720848
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90624305]
#  [0.87326839]
#  [0.88908549]]
# Loss:
# 0.00012204673589923753
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90624665]
#  [0.87326407]
#  [0.88908803]]
# Loss:
# 0.00012197402885651137
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90625022]
#  [0.87325974]
#  [0.88909055]]
# Loss:
# 0.00012190138415743936
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90625377]
#  [0.87325538]
#  [0.88909305]]
# Loss:
# 0.00012182880159926827
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9062573 ]
#  [0.873251  ]
#  [0.88909552]]
# Loss:
# 0.00012175628098758009
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90626081]
#  [0.8732466 ]
#  [0.88909797]]
# Loss:
# 0.00012168382213581439
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9062643 ]
#  [0.87324218]
#  [0.88910039]]
# Loss:
# 0.00012161142486481416
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90626776]
#  [0.87323775]
#  [0.8891028 ]]
# Loss:
# 0.00012153908900240476
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90627121]
#  [0.8732333 ]
#  [0.88910518]]
# Loss:
# 0.00012146681438298632
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
# ...
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90791485]
#  [0.87048091]
#  [0.8900532 ]]
# Loss:
# 8.530110136536914e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90791713]
#  [0.87047724]
#  [0.89005441]]
# Loss:
# 8.525707401592753e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90791942]
#  [0.87047357]
#  [0.89005561]]
# Loss:
# 8.521307870300921e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90792171]
#  [0.87046991]
#  [0.89005682]]
# Loss:
# 8.516911539709396e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90792399]
#  [0.87046624]
#  [0.89005802]]
# Loss:
# 8.51251840686959e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90792628]
#  [0.87046258]
#  [0.89005922]]
# Loss:
# 8.508128468835288e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90792856]
#  [0.87045892]
#  [0.89006042]]
# Loss:
# 8.503741722664454e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90793084]
#  [0.87045526]
#  [0.89006163]]
# Loss:
# 8.499358165417531e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90793313]
#  [0.8704516 ]
#  [0.89006283]]
# Loss:
# 8.494977794158415e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90793541]
#  [0.87044795]
#  [0.89006403]]
# Loss:
# 8.490600605954263e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90793769]
#  [0.87044429]
#  [0.89006523]]
# Loss:
# 8.486226597875141e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90793997]
#  [0.87044064]
#  [0.89006642]]
# Loss:
# 8.481855766994332e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90794225]
#  [0.87043699]
#  [0.89006762]]
# Loss:
# 8.477488110388352e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90794453]
#  [0.87043334]
#  [0.89006882]]
# Loss:
# 8.473123625136976e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90794681]
#  [0.87042969]
#  [0.89007002]]
# Loss:
# 8.468762308322598e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90794909]
#  [0.87042605]
#  [0.89007121]]
# Loss:
# 8.464404157031559e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90795136]
#  [0.87042241]
#  [0.89007241]]
# Loss:
# 8.460049168352457e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90795364]
#  [0.87041877]
#  [0.8900736 ]]
# Loss:
# 8.45569733937804e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90795591]
#  [0.87041513]
#  [0.89007479]]
# Loss:
# 8.45134866720312e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90795819]
#  [0.87041149]
#  [0.89007599]]
# Loss:
# 8.447003148926205e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90796046]
#  [0.87040785]
#  [0.89007718]]
# Loss:
# 8.442660781649227e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90796274]
#  [0.87040422]
#  [0.89007837]]
# Loss:
# 8.438321562476472e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90796501]
#  [0.87040059]
#  [0.89007956]]
# Loss:
# 8.433985488515638e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90796728]
#  [0.87039696]
#  [0.89008075]]
# Loss:
# 8.429652556877941e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90796955]
#  [0.87039333]
#  [0.89008194]]
# Loss:
# 8.425322764677492e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90797182]
#  [0.8703897 ]
#  [0.89008313]]
# Loss:
# 8.420996109030926e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90797409]
#  [0.87038608]
#  [0.89008432]]
# Loss:
# 8.416672587058846e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90797636]
#  [0.87038246]
#  [0.89008551]]
# Loss:
# 8.412352195884399e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90797863]
#  [0.87037883]
#  [0.89008669]]
# Loss:
# 8.408034932633813e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9079809 ]
#  [0.87037521]
#  [0.89008788]]
# Loss:
# 8.40372079443685e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90798316]
#  [0.8703716 ]
#  [0.89008906]]
# Loss:
# 8.399409778425909e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90798543]
#  [0.87036798]
#  [0.89009025]]
# Loss:
# 8.395101881736632e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9079877 ]
#  [0.87036437]
#  [0.89009143]]
# Loss:
# 8.390797101507791e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90798996]
#  [0.87036076]
#  [0.89009262]]
# Loss:
# 8.386495434881468e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90799223]
#  [0.87035715]
#  [0.8900938 ]]
# Loss:
# 8.382196879001958e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90799449]
#  [0.87035354]
#  [0.89009498]]
# Loss:
# 8.37790143101754e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90799675]
#  [0.87034993]
#  [0.89009616]]
# Loss:
# 8.373609088079043e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90799901]
#  [0.87034632]
#  [0.89009734]]
# Loss:
# 8.369319847340401e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90800127]
#  [0.87034272]
#  [0.89009852]]
# Loss:
# 8.365033705959282e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90800354]
#  [0.87033912]
#  [0.8900997 ]]
# Loss:
# 8.360750661095212e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90800579]
#  [0.87033552]
#  [0.89010088]]
# Loss:
# 8.356470709911845e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90800805]
#  [0.87033192]
#  [0.89010206]]
# Loss:
# 8.352193849574942e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90801031]
#  [0.87032833]
#  [0.89010323]]
# Loss:
# 8.347920077254069e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90801257]
#  [0.87032473]
#  [0.89010441]]
# Loss:
# 8.343649390121629e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90801483]
#  [0.87032114]
#  [0.89010559]]
# Loss:
# 8.339381785352804e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90801708]
#  [0.87031755]
#  [0.89010676]]
# Loss:
# 8.335117260125961e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90801934]
#  [0.87031396]
#  [0.89010794]]
# Loss:
# 8.330855811622673e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90802159]
#  [0.87031037]
#  [0.89010911]]
# Loss:
# 8.326597437027344e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90802385]
#  [0.87030679]
#  [0.89011028]]
# Loss:
# 8.322342133527151e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9080261 ]
#  [0.87030321]
#  [0.89011146]]
# Loss:
# 8.318089898312846e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90802835]
#  [0.87029962]
#  [0.89011263]]
# Loss:
# 8.313840728577735e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90803061]
#  [0.87029604]
#  [0.8901138 ]]
# Loss:
# 8.30959462151814e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90803286]
#  [0.87029247]
#  [0.89011497]]
# Loss:
# 8.305351574333936e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90803511]
#  [0.87028889]
#  [0.89011614]]
# Loss:
# 8.301111584227326e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90803736]
#  [0.87028531]
#  [0.89011731]]
# Loss:
# 8.29687464840377e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90803961]
#  [0.87028174]
#  [0.89011847]]
# Loss:
# 8.292640764071838e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90804186]
#  [0.87027817]
#  [0.89011964]]
# Loss:
# 8.288409928442873e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9080441 ]
#  [0.8702746 ]
#  [0.89012081]]
# Loss:
# 8.284182138731396e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90804635]
#  [0.87027103]
#  [0.89012198]]
# Loss:
# 8.279957392154758e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9080486 ]
#  [0.87026747]
#  [0.89012314]]
# Loss:
# 8.27573568593354e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90805084]
#  [0.8702639 ]
#  [0.89012431]]
# Loss:
# 8.271517017290835e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90805309]
#  [0.87026034]
#  [0.89012547]]
# Loss:
# 8.267301383452985e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90805533]
#  [0.87025678]
#  [0.89012663]]
# Loss:
# 8.263088781649538e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90805758]
#  [0.87025322]
#  [0.8901278 ]]
# Loss:
# 8.258879209112596e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90805982]
#  [0.87024967]
#  [0.89012896]]
# Loss:
# 8.25467266307756e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90806206]
#  [0.87024611]
#  [0.89013012]]
# Loss:
# 8.250469140782239e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9080643 ]
#  [0.87024256]
#  [0.89013128]]
# Loss:
# 8.24626863946812e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90806654]
#  [0.87023901]
#  [0.89013244]]
# Loss:
# 8.242071156379339e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90806878]
#  [0.87023546]
#  [0.8901336 ]]
# Loss:
# 8.237876688762624e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90807102]
#  [0.87023191]
#  [0.89013476]]
# Loss:
# 8.233685233868209e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90807326]
#  [0.87022836]
#  [0.89013592]]
# Loss:
# 8.229496788948812e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9080755 ]
#  [0.87022482]
#  [0.89013707]]
# Loss:
# 8.225311351260356e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90807774]
#  [0.87022127]
#  [0.89013823]]
# Loss:
# 8.221128918061712e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90807997]
#  [0.87021773]
#  [0.89013939]]
# Loss:
# 8.21694948661449e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90808221]
#  [0.87021419]
#  [0.89014054]]
# Loss:
# 8.212773054183344e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90808445]
#  [0.87021066]
#  [0.8901417 ]]
# Loss:
# 8.208599618035855e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90808668]
#  [0.87020712]
#  [0.89014285]]
# Loss:
# 8.204429175442502e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90808891]
#  [0.87020359]
#  [0.89014401]]
# Loss:
# 8.200261723676455e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90809115]
#  [0.87020005]
#  [0.89014516]]
# Loss:
# 8.196097260014319e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90809338]
#  [0.87019652]
#  [0.89014631]]
# Loss:
# 8.191935781735284e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90809561]
#  [0.87019299]
#  [0.89014746]]
# Loss:
# 8.187777286121176e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90809784]
#  [0.87018947]
#  [0.89014861]]
# Loss:
# 8.183621770457257e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90810007]
#  [0.87018594]
#  [0.89014976]]
# Loss:
# 8.179469232031338e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9081023 ]
#  [0.87018242]
#  [0.89015091]]
# Loss:
# 8.175319668134345e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90810453]
#  [0.8701789 ]
#  [0.89015206]]
# Loss:
# 8.17117307605978e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90810676]
#  [0.87017538]
#  [0.89015321]]
# Loss:
# 8.167029453104117e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90810899]
#  [0.87017186]
#  [0.89015436]]
# Loss:
# 8.162888796567087e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90811122]
#  [0.87016834]
#  [0.8901555 ]]
# Loss:
# 8.158751103750793e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90811344]
#  [0.87016483]
#  [0.89015665]]
# Loss:
# 8.15461637196063e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90811567]
#  [0.87016131]
#  [0.89015779]]
# Loss:
# 8.150484598504752e-05
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90811789]
#  [0.8701578 ]
#  [0.89015894]]
# Loss:
# 8.14635578069391e-05
