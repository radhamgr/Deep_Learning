# %% [markdown]
# Creating a Neural Network class in Python

# %%
import numpy as np
xAll = np.array(([2,9],[1,5],[3,6],[5,10]),dtype=float)
y = np.array(([92],[86],[89]),dtype=float)
 
#scale
xAll = xAll/np.amax(xAll,axis=0)
y = y/100 # s
# split data
X = np.split(xAll, [3])[0] # training data
xPredicted = np.split(xAll, [3])[1] # testing data

# %%
X
# Out:
# array([[0.4, 0.9],
#        [0.2, 0.5],
#        [0.6, 0.6]])

# %%
xPredicted
# Out:
# array([[1., 1.]])

# %%
class Neural_Network(object):
    def __init__(self):
        #parameters
        self.inputSize = 2
        self.outputSize = 1
        self.hiddenSize = 3
      
    # weights
        self.w1 = np.random.randn(self.inputSize,self.hiddenSize)
        self.w2 = np.random.randn(self.hiddenSize,self.outputSize)
    
    #actication function
    def sigmoid(self,s):
        return 1/(1+np.exp(-s))
    
    def forward(self,X):
        #forward propagation through our network
        self.z = np.dot(X,self.w1)
        self.z2 = self.sigmoid(self.z)
        self.z3 = np.dot(self.z2,self.w2)
        o = self.sigmoid(self.z3)
        return o
    
    def sigmoidPrime(self, s):
        #derivative of sigmoid
        return s * (1 - s)
    
    def back_propagation(self,X,y,o):
        self.o_error = y-o
        self.o_delta = self.o_error*self.sigmoidPrime(o)
        
        self.z2_error = self.o_delta*(self.w2.T)
        self.z2_delta = self.z2_error*self.sigmoidPrime(self.z2)
            
        self.w1 += X.T.dot(self.z2_delta)
        self.w2 += self.z2.T.dot(self.o_delta)
        
    def train (self, X, y):
        o = self.forward(X)
        self.back_propagation(X, y, o)

# %%
NN = Neural_Network()

#defining our output
o = NN.forward(X)

print("Predicted Output: \n" + str(o))
print("Actual Output: \n" + str(y))
# Out:
# Predicted Output:
# [[0.77133348]
#  [0.77125344]
#  [0.75611572]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]

# %%
NN = Neural_Network()
for i in range(1000): # trains the NN 1,000 times
    print("Input: \n" + str(X))
    print("Actual Output: \n" + str(y))
    print("Predicted Output: \n" + str(NN.forward(X)))
    print("Loss: \n" + str(np.mean(np.square(y - NN.forward(X)))))# mean sum squared loss
    print("\n")
    NN.train(X, y)
# Out:
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.67445772]
#  [0.61228794]
#  [0.64980158]]
# Loss:
# 0.05978251923531198
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.70948833]
#  [0.64839191]
#  [0.68648046]]
# Loss:
# 0.043504451241528797
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.73603409]
#  [0.67638069]
#  [0.71446922]]
# Loss:
# 0.03279018767566664
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.75667742]
#  [0.69855132]
#  [0.73634898]]
# Loss:
# 0.02544952622193972
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.77313035]
#  [0.7164915 ]
#  [0.75385804]]
# Loss:
# 0.020233338474829346
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.78653079]
#  [0.7312894 ]
#  [0.76816438]]
# Loss:
# 0.016408122906029558
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.7976502 ]
#  [0.74370072]
#  [0.78006619]]
# Loss:
# 0.013526811918703446
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.80702474]
#  [0.75426107]
#  [0.79012167]]
# Loss:
# 0.011306604029042632
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.81503639]
#  [0.76335836]
#  [0.79873047]]
# Loss:
# 0.00956236489132919
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.82196375]
#  [0.77127951]
#  [0.80618529]]
# Loss:
# 0.008169112676427214
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8280144 ]
#  [0.77824093]
#  [0.81270493]]
# Loss:
# 0.007040141326435182
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83334598]
#  [0.78440874]
#  [0.81845607]]
# Loss:
# 0.006113830235012645
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83808031]
#  [0.78991253]
#  [0.82356781]]
# Loss:
# 0.005345441357009181
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84231297]
#  [0.79485487]
#  [0.82814168]]
# Loss:
# 0.004701871832787272
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84612   ]
#  [0.79931798]
#  [0.8322586 ]]
# Loss:
# 0.004158210215287794
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84956269]
#  [0.80336859]
#  [0.8359839 ]]
# Loss:
# 0.003695423419297734
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85269094]
#  [0.80706142]
#  [0.83937089]]
# Loss:
# 0.003298770218724444
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85554585]
#  [0.81044176]
#  [0.84246348]]
# Loss:
# 0.002956692190629383
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85816158]
#  [0.81354748]
#  [0.84529824]]
# Loss:
# 0.0026600249048722396
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86056672]
#  [0.81641045]
#  [0.84790582]]
# Loss:
# 0.002401427976236813
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86278544]
#  [0.81905771]
#  [0.85031215]]
# Loss:
# 0.0021749672775135446
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8648383 ]
#  [0.82151239]
#  [0.8525393 ]]
# Loss:
# 0.001975804617525156
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86674289]
#  [0.82379433]
#  [0.85460617]]
# Loss:
# 0.0017999644236245636
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86851437]
#  [0.82592074]
#  [0.85652907]]
# Loss:
# 0.0016441563436291864
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87016587]
#  [0.82790654]
#  [0.85832215]]
# Loss:
# 0.0015056389599543008
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87170883]
#  [0.82976479]
#  [0.85999771]]
# Loss:
# 0.0013821140774489624
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87315326]
#  [0.83150696]
#  [0.86156654]]
# Loss:
# 0.0012716439908366996
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87450795]
#  [0.83314315]
#  [0.86303814]]
# Loss:
# 0.0011725861957779353
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87578069]
#  [0.83468231]
#  [0.86442088]]
# Loss:
# 0.0010835414641416248
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87697834]
#  [0.8361324 ]
#  [0.86572221]]
# Loss:
# 0.0010033122469411445
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87810704]
#  [0.83750052]
#  [0.86694874]]
# Loss:
# 0.0009308691232089075
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87917227]
#  [0.83879302]
#  [0.86810638]]
# Loss:
# 0.0008653235650095461
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88017891]
#  [0.84001561]
#  [0.86920043]]
# Loss:
# 0.0008059056962411672
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88113139]
#  [0.84117343]
#  [0.87023566]]
# Loss:
# 0.0007519460263898794
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88203366]
#  [0.84227112]
#  [0.87121637]]
# Loss:
# 0.0007028603684240261
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88288932]
#  [0.84331289]
#  [0.87214643]]
# Loss:
# 0.0006581373226989969
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88370163]
#  [0.84430256]
#  [0.87302938]]
# Loss:
# 0.0006173278405157229
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88447353]
#  [0.84524361]
#  [0.87386841]]
# Loss:
# 0.0005800364822532447
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88520772]
#  [0.84613922]
#  [0.87466644]]
# Loss:
# 0.000545914063367218
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88590666]
#  [0.84699228]
#  [0.87542614]]
# Loss:
# 0.0005146514425855524
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88657259]
#  [0.84780546]
#  [0.87614994]]
# Loss:
# 0.00048597425446570943
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88720758]
#  [0.84858119]
#  [0.87684008]]
# Loss:
# 0.0004596384261822899
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88781353]
#  [0.84932174]
#  [0.87749862]]
# Loss:
# 0.00043542634829982
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88839216]
#  [0.85002916]
#  [0.87812743]]
# Loss:
# 0.00041314359310067804
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8889451 ]
#  [0.85070538]
#  [0.87872828]]
# Loss:
# 0.00039261609311229477
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88947383]
#  [0.85135216]
#  [0.87930276]]
# Loss:
# 0.0003736877078289163
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88997971]
#  [0.85197115]
#  [0.87985238]]
# Loss:
# 0.00035621811903523127
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89046403]
#  [0.85256386]
#  [0.88037851]]
# Loss:
# 0.000340081005219931
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89092795]
#  [0.85313171]
#  [0.88088243]]
# Loss:
# 0.0003251624537889323
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89137259]
#  [0.85367602]
#  [0.88136534]]
# Loss:
# 0.00031135957652153547
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89179896]
#  [0.85419801]
#  [0.88182835]]
# Loss:
# 0.00029857929924848335
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89220801]
#  [0.85469882]
#  [0.88227249]]
# Loss:
# 0.00028673730129968167
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89260063]
#  [0.85517953]
#  [0.88269872]]
# Loss:
# 0.0002757570840531634
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89297765]
#  [0.85564113]
#  [0.88310796]]
# Loss:
# 0.00026556915106206396
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89333985]
#  [0.85608456]
#  [0.88350104]]
# Loss:
# 0.0002561102848590813
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89368795]
#  [0.8565107 ]
#  [0.88387876]]
# Loss:
# 0.0002473229077322361
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89402264]
#  [0.85692038]
#  [0.88424185]]
# Loss:
# 0.00023915451560728638
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89434456]
#  [0.85731436]
#  [0.88459101]]
# Loss:
# 0.00023155717572240163
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8946543 ]
#  [0.85769337]
#  [0.88492691]]
# Loss:
# 0.00022448708008923453
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89495244]
#  [0.85805811]
#  [0.88525014]]
# Loss:
# 0.00021790414784261702
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8952395 ]
#  [0.85840922]
#  [0.8855613 ]]
# Loss:
# 0.00021177167052138324
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89551599]
#  [0.8587473 ]
#  [0.88586092]]
# Loss:
# 0.00020605599512340685
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89578238]
#  [0.85907293]
#  [0.88614953]]
# Loss:
# 0.00020072624046077675
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89603912]
#  [0.85938666]
#  [0.88642761]]
# Loss:
# 0.000195754042925342
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89628662]
#  [0.859689  ]
#  [0.88669562]]
# Loss:
# 0.00019111332827558415
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8965253 ]
#  [0.85998044]
#  [0.88695399]]
# Loss:
# 0.00018678010648627317
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89675552]
#  [0.86026143]
#  [0.88720313]]
# Loss:
# 0.00018273228707305135
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89697764]
#  [0.86053241]
#  [0.88744344]]
# Loss:
# 0.0001789495126239802
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89719201]
#  [0.8607938 ]
#  [0.88767529]]
# Loss:
# 0.00017541300854697904
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89739894]
#  [0.86104599]
#  [0.88789902]]
# Loss:
# 0.00017210544728173835
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89759873]
#  [0.86128936]
#  [0.88811497]]
# Loss:
# 0.00016901082543318527
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89779169]
#  [0.86152425]
#  [0.88832345]]
# Loss:
# 0.00016611435246468098
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89797809]
#  [0.86175101]
#  [0.88852476]]
# Loss:
# 0.00016340234974717642
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89815818]
#  [0.86196995]
#  [0.88871919]]
# Loss:
# 0.0001608621588984435
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89833221]
#  [0.86218139]
#  [0.88890701]]
# Loss:
# 0.00015848205846733519
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89850043]
#  [0.86238561]
#  [0.88908848]]
# Loss:
# 0.0001562511881235949
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89866306]
#  [0.86258289]
#  [0.88926385]]
# Loss:
# 0.00015415947960680437
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89882031]
#  [0.8627735 ]
#  [0.88943334]]
# Loss:
# 0.0001521975937694501
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89897239]
#  [0.86295769]
#  [0.88959719]]
# Loss:
# 0.00015035686312119697
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8991195 ]
#  [0.8631357 ]
#  [0.88975561]]
# Loss:
# 0.00014862923934468226
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89926182]
#  [0.86330776]
#  [0.8899088 ]]
# Loss:
# 0.00014700724530926294
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89939953]
#  [0.86347409]
#  [0.89005696]]
# Loss:
# 0.00014548393115856566
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89953281]
#  [0.8636349 ]
#  [0.89020028]]
# Loss:
# 0.00014405283409173243
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89966181]
#  [0.8637904 ]
#  [0.89033892]]
# Loss:
# 0.0001427079414969957
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8997867 ]
#  [0.86394077]
#  [0.89047307]]
# Loss:
# 0.0001414436571309669
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89990762]
#  [0.8640862 ]
#  [0.89060288]]
# Loss:
# 0.0001402547700676356
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90002471]
#  [0.86422687]
#  [0.89072852]]
# Loss:
# 0.00013913642616857912
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90013812]
#  [0.86436295]
#  [0.89085013]]
# Loss:
# 0.00013808410185024527
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90024797]
#  [0.86449459]
#  [0.89096785]]
# Loss:
# 0.0001370935799459926
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90035439]
#  [0.86462197]
#  [0.89108182]]
# Loss:
# 0.00013616092748008286
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90045751]
#  [0.86474521]
#  [0.89119218]]
# Loss:
# 0.00013528247518825587
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90055743]
#  [0.86486448]
#  [0.89129906]]
# Loss:
# 0.00013445479863515993
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90065426]
#  [0.8649799 ]
#  [0.89140256]]
# Loss:
# 0.000133674700792918
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90074812]
#  [0.86509161]
#  [0.89150281]]
# Loss:
# 0.00013293919595771134
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90083911]
#  [0.86519973]
#  [0.89159992]]
# Loss:
# 0.00013224549489259863
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90092733]
#  [0.86530439]
#  [0.891694  ]]
# Loss:
# 0.00013159099109496202
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90101286]
#  [0.8654057 ]
#  [0.89178515]]
# Loss:
# 0.00013097324809611147
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90109581]
#  [0.86550378]
#  [0.89187348]]
# Loss:
# 0.0001303899877089656
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90117625]
#  [0.86559874]
#  [0.89195907]]
# Loss:
# 0.0001298390791470196
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90125428]
#  [0.86569068]
#  [0.89204201]]
# Loss:
# 0.0001293185289447779
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90132997]
#  [0.86577969]
#  [0.8921224 ]]
# Loss:
# 0.0001288264716157085
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9014034 ]
#  [0.86586589]
#  [0.89220033]]
# Loss:
# 0.00012836116098949136
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90147465]
#  [0.86594935]
#  [0.89227586]]
# Loss:
# 0.00012792096217519703
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90154379]
#  [0.86603018]
#  [0.89234909]]
# Loss:
# 0.00012750434410168317
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90161088]
#  [0.86610845]
#  [0.89242008]]
# Loss:
# 0.00012710987259049298
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.901676  ]
#  [0.86618424]
#  [0.89248892]]
# Loss:
# 0.00012673620392042236
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90173921]
#  [0.86625765]
#  [0.89255566]]
# Loss:
# 0.00012638207884619376
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90180056]
#  [0.86632875]
#  [0.89262039]]
# Loss:
# 0.00012604631703687106
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90186013]
#  [0.8663976 ]
#  [0.89268316]]
# Loss:
# 0.00012572781190238534
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90191797]
#  [0.86646429]
#  [0.89274403]]
# Loss:
# 0.00012542552577918148
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90197413]
#  [0.86652889]
#  [0.89280308]]
# Loss:
# 0.00012513848544828607
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90202867]
#  [0.86659145]
#  [0.89286035]]
# Loss:
# 0.00012486577796125183
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90208164]
#  [0.86665204]
#  [0.8929159 ]]
# Loss:
# 0.00012460654675141458
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90213309]
#  [0.86671074]
#  [0.89296979]]
# Loss:
# 0.0001243599880096234
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90218307]
#  [0.86676759]
#  [0.89302208]]
# Loss:
# 0.0001241253473052733
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90223163]
#  [0.86682265]
#  [0.8930728 ]]
# Loss:
# 0.00012390191643500798
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9022788 ]
#  [0.86687598]
#  [0.89312201]]
# Loss:
# 0.0001236890304827031
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90232463]
#  [0.86692764]
#  [0.89316977]]
# Loss:
# 0.00012348606507574383
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90236918]
#  [0.86697768]
#  [0.8932161 ]]
# Loss:
# 0.00012329243382365256
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90241246]
#  [0.86702614]
#  [0.89326107]]
# Loss:
# 0.00012310758592621606
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90245453]
#  [0.86707309]
#  [0.8933047 ]]
# Loss:
# 0.00012293100393924406
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90249543]
#  [0.86711855]
#  [0.89334705]]
# Loss:
# 0.00012276220168696664
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90253518]
#  [0.86716259]
#  [0.89338815]]
# Loss:
# 0.00012260072231087222
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90257383]
#  [0.86720523]
#  [0.89342804]]
# Loss:
# 0.00012244613644560355
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9026114 ]
#  [0.86724654]
#  [0.89346676]]
# Loss:
# 0.00012229804051316117
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90264794]
#  [0.86728654]
#  [0.89350435]]
# Loss:
# 0.0001221560551273264
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90268347]
#  [0.86732529]
#  [0.89354083]]
# Loss:
# 0.00012201982360082384
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90271803]
#  [0.8673628 ]
#  [0.89357624]]
# Loss:
# 0.00012188901054823852
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90275163]
#  [0.86739913]
#  [0.89361063]]
# Loss:
# 0.00012176330057826327
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90278433]
#  [0.86743432]
#  [0.893644  ]]
# Loss:
# 0.00012164239706924926
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90281613]
#  [0.86746838]
#  [0.89367641]]
# Loss:
# 0.0001215260210225214
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90284707]
#  [0.86750137]
#  [0.89370787]]
# Loss:
# 0.00012141390998826204
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90287718]
#  [0.8675333 ]
#  [0.89373842]]
# Loss:
# 0.00012130581705918137
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90290648]
#  [0.86756422]
#  [0.89376809]]
# Loss:
# 0.00012120150992745377
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90293499]
#  [0.86759416]
#  [0.89379689]]
# Loss:
# 0.0001211007700008294
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90296273]
#  [0.86762314]
#  [0.89382486]]
# Loss:
# 0.00012100339157398597
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90298974]
#  [0.86765119]
#  [0.89385202]]
# Loss:
# 0.00012090918105154849
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90301604]
#  [0.86767834]
#  [0.8938784 ]]
# Loss:
# 0.00012081795621941816
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90304163]
#  [0.86770461]
#  [0.89390402]]
# Loss:
# 0.00012072954556127647
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90306656]
#  [0.86773005]
#  [0.8939289 ]]
# Loss:
# 0.0001206437876173494
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90309083]
#  [0.86775466]
#  [0.89395306]]
# Loss:
# 0.00012056053038273988
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90311446]
#  [0.86777847]
#  [0.89397653]]
# Loss:
# 0.00012047963074272774
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90313748]
#  [0.86780151]
#  [0.89399933]]
# Loss:
# 0.00012040095394278434
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9031599 ]
#  [0.8678238 ]
#  [0.89402147]]
# Loss:
# 0.00012032437309097281
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90318174]
#  [0.86784536]
#  [0.89404298]]
# Loss:
# 0.00012024976869079244
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90320302]
#  [0.86786622]
#  [0.89406388]]
# Loss:
# 0.00012017702820244171
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90322375]
#  [0.86788639]
#  [0.89408418]]
# Loss:
# 0.0001201060456307857
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90324396]
#  [0.8679059 ]
#  [0.89410389]]
# Loss:
# 0.0001200367211383073
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90326365]
#  [0.86792477]
#  [0.89412305]]
# Loss:
# 0.00011996896068149848
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90328284]
#  [0.867943  ]
#  [0.89414166]]
# Loss:
# 0.00011990267566919725
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90330155]
#  [0.86796063]
#  [0.89415974]]
# Loss:
# 0.0001198377826415488
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90331979]
#  [0.86797767]
#  [0.89417731]]
# Loss:
# 0.00011977420296827361
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90333757]
#  [0.86799414]
#  [0.89419438]]
# Loss:
# 0.00011971186256504091
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90335492]
#  [0.86801005]
#  [0.89421097]]
# Loss:
# 0.00011965069162687718
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90337183]
#  [0.86802543]
#  [0.89422709]]
# Loss:
# 0.00011959062437748518
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90338832]
#  [0.86804028]
#  [0.89424275]]
# Loss:
# 0.00011953159883357964
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90340442]
#  [0.86805462]
#  [0.89425797]]
# Loss:
# 0.00011947355658322702
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90342012]
#  [0.86806847]
#  [0.89427276]]
# Loss:
# 0.00011941644257742639
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90343543]
#  [0.86808185]
#  [0.89428714]]
# Loss:
# 0.00011936020493404145
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90345038]
#  [0.86809476]
#  [0.8943011 ]]
# Loss:
# 0.00011930479475338671
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90346497]
#  [0.86810721]
#  [0.89431468]]
# Loss:
# 0.00011925016594472183
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90347921]
#  [0.86811923]
#  [0.89432788]]
# Loss:
# 0.00011919627506302536
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90349312]
#  [0.86813083]
#  [0.8943407 ]]
# Loss:
# 0.0001191430811553981
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90350669]
#  [0.86814201]
#  [0.89435317]]
# Loss:
# 0.00011909054561653
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90351995]
#  [0.8681528 ]
#  [0.89436529]]
# Loss:
# 0.0001190386320526764
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9035329 ]
#  [0.86816319]
#  [0.89437707]]
# Loss:
# 0.00011898730615364332
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90354554]
#  [0.86817321]
#  [0.89438852]]
# Loss:
# 0.00011893653557227488
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9035579 ]
#  [0.86818286]
#  [0.89439965]]
# Loss:
# 0.00011888628981103278
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90356997]
#  [0.86819215]
#  [0.89441047]]
# Loss:
# 0.00011883654011520492
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90358176]
#  [0.8682011 ]
#  [0.89442099]]
# Loss:
# 0.0001187872593723629
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90359329]
#  [0.86820972]
#  [0.89443122]]
# Loss:
# 0.0001187384220177123
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90360456]
#  [0.86821801]
#  [0.89444117]]
# Loss:
# 0.0001186900039449486
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90361558]
#  [0.86822598]
#  [0.89445084]]
# Loss:
# 0.00011864198242232161
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90362635]
#  [0.86823365]
#  [0.89446024]]
# Loss:
# 0.00011859433601359489
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90363689]
#  [0.86824102]
#  [0.89446939]]
# Loss:
# 0.00011854704450358268
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9036472 ]
#  [0.8682481 ]
#  [0.89447828]]
# Loss:
# 0.0001185000888280497
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90365728]
#  [0.8682549 ]
#  [0.89448692]]
# Loss:
# 0.00011845345100765307
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90366714]
#  [0.86826142]
#  [0.89449533]]
# Loss:
# 0.00011840711408571784
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9036768 ]
#  [0.86826768]
#  [0.89450351]]
# Loss:
# 0.00011836106206963555
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90368624]
#  [0.86827369]
#  [0.89451147]]
# Loss:
# 0.00011831527987564941
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90369549]
#  [0.86827944]
#  [0.8945192 ]]
# Loss:
# 0.00011826975327682884
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90370455]
#  [0.86828495]
#  [0.89452673]]
# Loss:
# 0.00011822446885404566
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90371342]
#  [0.86829023]
#  [0.89453405]]
# Loss:
# 0.0001181794139498008
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9037221 ]
#  [0.86829528]
#  [0.89454117]]
# Loss:
# 0.00011813457662470038
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90373061]
#  [0.8683001 ]
#  [0.89454809]]
# Loss:
# 0.0001180899456164378
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90373895]
#  [0.86830471]
#  [0.89455483]]
# Loss:
# 0.00011804551030115711
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90374712]
#  [0.86830912]
#  [0.89456139]]
# Loss:
# 0.00011800126065702076
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90375513]
#  [0.86831331]
#  [0.89456777]]
# Loss:
# 0.00011795718722988461
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90376298]
#  [0.86831731]
#  [0.89457397]]
# Loss:
# 0.00011791328110094541
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90377067]
#  [0.86832112]
#  [0.89458001]]
# Loss:
# 0.00011786953385623489
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90377822]
#  [0.86832474]
#  [0.89458589]]
# Loss:
# 0.00011782593755788513
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90378563]
#  [0.86832818]
#  [0.89459161]]
# Loss:
# 0.00011778248471702503
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90379289]
#  [0.86833145]
#  [0.89459718]]
# Loss:
# 0.00011773916826823701
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90380002]
#  [0.86833454]
#  [0.89460259]]
# Loss:
# 0.00011769598154547615
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90380701]
#  [0.86833747]
#  [0.89460787]]
# Loss:
# 0.00011765291825937528
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90381388]
#  [0.86834024]
#  [0.894613  ]]
# Loss:
# 0.00011760997247582759
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90382062]
#  [0.86834285]
#  [0.89461799]]
# Loss:
# 0.00011756713859582504
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90382724]
#  [0.86834531]
#  [0.89462286]]
# Loss:
# 0.00011752441133641982
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90383374]
#  [0.86834763]
#  [0.89462759]]
# Loss:
# 0.00011748178571279064
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90384013]
#  [0.8683498 ]
#  [0.8946322 ]]
# Loss:
# 0.00011743925702132936
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90384641]
#  [0.86835183]
#  [0.89463669]]
# Loss:
# 0.00011739682082368812
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90385258]
#  [0.86835372]
#  [0.89464106]]
# Loss:
# 0.0001173544729317438
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90385864]
#  [0.86835549]
#  [0.89464532]]
# Loss:
# 0.00011731220939341205
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9038646 ]
#  [0.86835712]
#  [0.89464946]]
# Loss:
# 0.0001172700264792772
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90387046]
#  [0.86835864]
#  [0.8946535 ]]
# Loss:
# 0.0001172279206699698
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90387623]
#  [0.86836003]
#  [0.89465743]]
# Loss:
# 0.00011718588864428187
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90388191]
#  [0.86836131]
#  [0.89466126]]
# Loss:
# 0.00011714392726795213
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90388749]
#  [0.86836247]
#  [0.89466499]]
# Loss:
# 0.00011710203358307177
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90389298]
#  [0.86836352]
#  [0.89466862]]
# Loss:
# 0.00011706020479811654
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90389839]
#  [0.86836447]
#  [0.89467216]]
# Loss:
# 0.00011701843827853553
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90390372]
#  [0.86836531]
#  [0.89467562]]
# Loss:
# 0.00011697673153787139
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90390896]
#  [0.86836606]
#  [0.89467898]]
# Loss:
# 0.00011693508222938798
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90391413]
#  [0.8683667 ]
#  [0.89468225]]
# Loss:
# 0.00011689348813817573
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90391922]
#  [0.86836725]
#  [0.89468545]]
# Loss:
# 0.00011685194717369792
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90392423]
#  [0.86836771]
#  [0.89468856]]
# Loss:
# 0.00011681045736276702
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90392918]
#  [0.86836807]
#  [0.89469159]]
# Loss:
# 0.00011676901684291928
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90393405]
#  [0.86836835]
#  [0.89469455]]
# Loss:
# 0.00011672762385616109
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90393886]
#  [0.86836855]
#  [0.89469743]]
# Loss:
# 0.0001166862767430593
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9039436 ]
#  [0.86836866]
#  [0.89470024]]
# Loss:
# 0.00011664497393719903
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90394827]
#  [0.86836869]
#  [0.89470299]]
# Loss:
# 0.00011660371395991365
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90395288]
#  [0.86836865]
#  [0.89470566]]
# Loss:
# 0.0001165624954153479
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90395744]
#  [0.86836853]
#  [0.89470827]]
# Loss:
# 0.00011652131698577756
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90396193]
#  [0.86836834]
#  [0.89471081]]
# Loss:
# 0.00011648017742721225
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90396637]
#  [0.86836808]
#  [0.89471329]]
# Loss:
# 0.0001164390755652209
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90397075]
#  [0.86836774]
#  [0.89471571]]
# Loss:
# 0.00011639801029102441
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90397507]
#  [0.86836734]
#  [0.89471807]]
# Loss:
# 0.00011635698055779485
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90397935]
#  [0.86836688]
#  [0.89472038]]
# Loss:
# 0.00011631598537714976
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90398357]
#  [0.86836635]
#  [0.89472263]]
# Loss:
# 0.00011627502381587039
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90398774]
#  [0.86836576]
#  [0.89472482]]
# Loss:
# 0.00011623409499279141
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90399187]
#  [0.86836511]
#  [0.89472697]]
# Loss:
# 0.00011619319807586858
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90399595]
#  [0.86836441]
#  [0.89472906]]
# Loss:
# 0.00011615233227940372
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90399998]
#  [0.86836365]
#  [0.8947311 ]]
# Loss:
# 0.00011611149686144073
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90400397]
#  [0.86836283]
#  [0.8947331 ]]
# Loss:
# 0.00011607069112131216
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90400792]
#  [0.86836196]
#  [0.89473504]]
# Loss:
# 0.00011602991439728838
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90401182]
#  [0.86836104]
#  [0.89473695]]
# Loss:
# 0.0001159891660644123
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90401568]
#  [0.86836007]
#  [0.89473881]]
# Loss:
# 0.00011594844553241392
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90401951]
#  [0.86835905]
#  [0.89474062]]
# Loss:
# 0.0001159077522437623
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90402329]
#  [0.86835798]
#  [0.8947424 ]]
# Loss:
# 0.00011586708567182194
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90402704]
#  [0.86835687]
#  [0.89474413]]
# Loss:
# 0.0001158264453191094
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90403076]
#  [0.86835571]
#  [0.89474583]]
# Loss:
# 0.00011578583071566996
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90403443]
#  [0.86835451]
#  [0.89474748]]
# Loss:
# 0.00011574524141750641
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90403808]
#  [0.86835327]
#  [0.8947491 ]]
# Loss:
# 0.00011570467700513177
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90404169]
#  [0.86835198]
#  [0.89475069]]
# Loss:
# 0.00011566413708218878
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90404526]
#  [0.86835066]
#  [0.89475223]]
# Loss:
# 0.00011562362127414598
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90404881]
#  [0.8683493 ]
#  [0.89475375]]
# Loss:
# 0.00011558312922707494
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90405233]
#  [0.8683479 ]
#  [0.89475523]]
# Loss:
# 0.00011554266060648613
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90405581]
#  [0.86834647]
#  [0.89475668]]
# Loss:
# 0.00011550221509623979
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90405927]
#  [0.868345  ]
#  [0.8947581 ]]
# Loss:
# 0.00011546179239751579
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9040627 ]
#  [0.8683435 ]
#  [0.89475949]]
# Loss:
# 0.0001154213922278297
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9040661 ]
#  [0.86834196]
#  [0.89476085]]
# Loss:
# 0.00011538101432012608
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90406948]
#  [0.86834039]
#  [0.89476218]]
# Loss:
# 0.00011534065842190852
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90407283]
#  [0.86833879]
#  [0.89476348]]
# Loss:
# 0.00011530032429441573
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90407615]
#  [0.86833716]
#  [0.89476476]]
# Loss:
# 0.00011526001171185581
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90407946]
#  [0.8683355 ]
#  [0.89476601]]
# Loss:
# 0.00011521972046067235
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90408273]
#  [0.86833381]
#  [0.89476723]]
# Loss:
# 0.00011517945033886263
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90408599]
#  [0.8683321 ]
#  [0.89476843]]
# Loss:
# 0.00011513920115532087
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90408922]
#  [0.86833036]
#  [0.8947696 ]]
# Loss:
# 0.00011509897272923494
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90409243]
#  [0.86832859]
#  [0.89477076]]
# Loss:
# 0.0001150587648895012
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90409562]
#  [0.86832679]
#  [0.89477189]]
# Loss:
# 0.0001150185774741766
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90409879]
#  [0.86832497]
#  [0.89477299]]
# Loss:
# 0.00011497841032997526
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90410194]
#  [0.86832313]
#  [0.89477408]]
# Loss:
# 0.0001149382633117734
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90410507]
#  [0.86832127]
#  [0.89477514]]
# Loss:
# 0.00011489813628214785
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90410818]
#  [0.86831938]
#  [0.89477619]]
# Loss:
# 0.00011485802911095374
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90411127]
#  [0.86831747]
#  [0.89477721]]
# Loss:
# 0.000114817941674913
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90411434]
#  [0.86831554]
#  [0.89477822]]
# Loss:
# 0.00011477787385721584
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9041174 ]
#  [0.86831358]
#  [0.89477921]]
# Loss:
# 0.00011473782554717459
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90412044]
#  [0.86831161]
#  [0.89478018]]
# Loss:
# 0.00011469779663987637
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90412346]
#  [0.86830962]
#  [0.89478113]]
# Loss:
# 0.00011465778703584807
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90412647]
#  [0.86830761]
#  [0.89478207]]
# Loss:
# 0.00011461779664075987
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90412947]
#  [0.86830558]
#  [0.89478298]]
# Loss:
# 0.00011457782536513816
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90413244]
#  [0.86830353]
#  [0.89478389]]
# Loss:
# 0.00011453787312409092
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90413541]
#  [0.86830147]
#  [0.89478477]]
# Loss:
# ...
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90414712]
#  [0.86829305]
#  [0.89478817]]
# Loss:
# 0.00011433839475548018
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90415001]
#  [0.86829091]
#  [0.89478899]]
# Loss:
# 0.00011429855516490864
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9041529 ]
#  [0.86828876]
#  [0.89478979]]
# Loss:
# 0.00011425873412300944
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90415577]
#  [0.86828658]
#  [0.89479058]]
# Loss:
# 0.00011421893157339217
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90415863]
#  [0.8682844 ]
#  [0.89479136]]
# Loss:
# 0.00011417914746238524
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90416148]
#  [0.8682822 ]
#  [0.89479212]]
# Loss:
# 0.00011413938173888761
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90416431]
#  [0.86827999]
#  [0.89479288]]
# Loss:
# 0.0001140996343542296
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90416714]
#  [0.86827777]
#  [0.89479362]]
# Loss:
# 0.00011405990526202323
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90416996]
#  [0.86827554]
#  [0.89479435]]
# Loss:
# 0.00011402019441805283
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90417276]
#  [0.86827329]
#  [0.89479507]]
# Loss:
# 0.00011398050178013005
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90417556]
#  [0.86827103]
#  [0.89479578]]
# Loss:
# 0.00011394082730800404
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90417834]
#  [0.86826877]
#  [0.89479648]]
# Loss:
# 0.00011390117096323626
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90418112]
#  [0.86826649]
#  [0.89479717]]
# Loss:
# 0.00011386153270910262
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90418389]
#  [0.8682642 ]
#  [0.89479785]]
# Loss:
# 0.00011382191251050338
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90418665]
#  [0.8682619 ]
#  [0.89479852]]
# Loss:
# 0.00011378231033386302
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9041894 ]
#  [0.86825959]
#  [0.89479918]]
# Loss:
# 0.00011374272614705223
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90419214]
#  [0.86825727]
#  [0.89479983]]
# Loss:
# 0.00011370315991929973
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90419487]
#  [0.86825494]
#  [0.89480048]]
# Loss:
# 0.00011366361162112809
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9041976 ]
#  [0.86825261]
#  [0.89480111]]
# Loss:
# 0.00011362408122426306
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420031]
#  [0.86825026]
#  [0.89480174]]
# Loss:
# 0.0001135845687015859
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420302]
#  [0.86824791]
#  [0.89480236]]
# Loss:
# 0.00011354507402705246
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420573]
#  [0.86824555]
#  [0.89480297]]
# Loss:
# 0.00011350559717563908
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420842]
#  [0.86824318]
#  [0.89480358]]
# Loss:
# 0.00011346613812329092
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421111]
#  [0.86824081]
#  [0.89480418]]
# Loss:
# 0.00011342669684685894
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421379]
#  [0.86823842]
#  [0.89480477]]
# Loss:
# 0.00011338727332405262
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421647]
#  [0.86823603]
#  [0.89480535]]
# Loss:
# 0.00011334786753339615
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421913]
#  [0.86823364]
#  [0.89480593]]
# Loss:
# 0.00011330847945417281
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042218 ]
#  [0.86823123]
#  [0.8948065 ]]
# Loss:
# 0.00011326910906639345
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422445]
#  [0.86822882]
#  [0.89480707]]
# Loss:
# 0.00011322975635074669
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042271 ]
#  [0.86822641]
#  [0.89480763]]
# Loss:
# 0.00011319042128856528
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422975]
#  [0.86822398]
#  [0.89480818]]
# Loss:
# 0.00011315110386179337
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423239]
#  [0.86822155]
#  [0.89480873]]
# Loss:
# 0.0001131118040529447
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423502]
#  [0.86821912]
#  [0.89480927]]
# Loss:
# 0.00011307252184507803
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423765]
#  [0.86821668]
#  [0.8948098 ]]
# Loss:
# 0.00011303325722175732
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424027]
#  [0.86821424]
#  [0.89481033]]
# Loss:
# 0.00011299401016703739
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424289]
#  [0.86821179]
#  [0.89481086]]
# Loss:
# 0.00011295478066542307
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042455 ]
#  [0.86820933]
#  [0.89481138]]
# Loss:
# 0.00011291556870184827
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424811]
#  [0.86820687]
#  [0.8948119 ]]
# Loss:
# 0.00011287637426166002
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425071]
#  [0.86820441]
#  [0.89481241]]
# Loss:
# 0.00011283719733058331
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425331]
#  [0.86820194]
#  [0.89481292]]
# Loss:
# 0.00011279803789470556
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425591]
#  [0.86819947]
#  [0.89481342]]
# Loss:
# 0.00011275889594045736
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042585 ]
#  [0.86819699]
#  [0.89481392]]
# Loss:
# 0.00011271977145459128
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426108]
#  [0.86819451]
#  [0.89481441]]
# Loss:
# 0.00011268066442416553
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426367]
#  [0.86819202]
#  [0.8948149 ]]
# Loss:
# 0.00011264157483652504
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426624]
#  [0.86818953]
#  [0.89481539]]
# Loss:
# 0.00011260250267928774
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426882]
#  [0.86818704]
#  [0.89481587]]
# Loss:
# 0.0001125634479403264
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427139]
#  [0.86818454]
#  [0.89481635]]
# Loss:
# 0.00011252441060775776
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427395]
#  [0.86818204]
#  [0.89481682]]
# Loss:
# 0.00011248539066992854
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427652]
#  [0.86817954]
#  [0.89481729]]
# Loss:
# 0.00011244638811539636
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427907]
#  [0.86817704]
#  [0.89481776]]
# Loss:
# 0.00011240740293293112
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428163]
#  [0.86817453]
#  [0.89481822]]
# Loss:
# 0.00011236843511148717
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428418]
#  [0.86817201]
#  [0.89481868]]
# Loss:
# 0.00011232948464020663
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428673]
#  [0.8681695 ]
#  [0.89481914]]
# Loss:
# 0.00011229055150840228
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428928]
#  [0.86816698]
#  [0.8948196 ]]
# Loss:
# 0.00011225163570554702
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90429182]
#  [0.86816446]
#  [0.89482005]]
# Loss:
# 0.00011221273722127023
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90429436]
#  [0.86816194]
#  [0.8948205 ]]
# Loss:
# 0.00011217385604534289
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042969 ]
#  [0.86815941]
#  [0.89482094]]
# Loss:
# 0.00011213499216768125
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90429943]
#  [0.86815688]
#  [0.89482139]]
# Loss:
# 0.00011209614557831747
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90430196]
#  [0.86815435]
#  [0.89482183]]
# Loss:
# 0.00011205731626741685
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90430449]
#  [0.86815182]
#  [0.89482227]]
# Loss:
# 0.00011201850422525713
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90430701]
#  [0.86814929]
#  [0.8948227 ]]
# Loss:
# 0.00011197970944222454
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90430954]
#  [0.86814675]
#  [0.89482314]]
# Loss:
# 0.00011194093190881005
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90431206]
#  [0.86814421]
#  [0.89482357]]
# Loss:
# 0.00011190217161559856
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90431457]
#  [0.86814167]
#  [0.89482399]]
# Loss:
# 0.00011186342855327374
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90431709]
#  [0.86813913]
#  [0.89482442]]
# Loss:
# 0.00011182470271259766
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9043196 ]
#  [0.86813658]
#  [0.89482484]]
# Loss:
# 0.00011178599408442112
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90432211]
#  [0.86813404]
#  [0.89482527]]
# Loss:
# 0.00011174730265967301
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90432462]
#  [0.86813149]
#  [0.89482569]]
# Loss:
# 0.00011170862842935362
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90432713]
#  [0.86812894]
#  [0.8948261 ]]
# Loss:
# 0.00011166997138453167
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90432963]
#  [0.86812639]
#  [0.89482652]]
# Loss:
# 0.00011163133151634532
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90433213]
#  [0.86812384]
#  [0.89482693]]
# Loss:
# 0.00011159270881599509
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90433463]
#  [0.86812129]
#  [0.89482735]]
# Loss:
# 0.00011155410327473522
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90433713]
#  [0.86811873]
#  [0.89482776]]
# Loss:
# 0.00011151551488388177
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90433962]
#  [0.86811618]
#  [0.89482816]]
# Loss:
# 0.00011147694363480196
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90434212]
#  [0.86811362]
#  [0.89482857]]
# Loss:
# 0.0001114383895189085
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90434461]
#  [0.86811106]
#  [0.89482898]]
# Loss:
# 0.0001113998525276695
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9043471 ]
#  [0.8681085 ]
#  [0.89482938]]
# Loss:
# 0.00011136133265259058
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90434959]
#  [0.86810594]
#  [0.89482978]]
# Loss:
# 0.00011132282988522582
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90435207]
#  [0.86810338]
#  [0.89483018]]
# Loss:
# 0.00011128434421716383
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90435456]
#  [0.86810082]
#  [0.89483058]]
# Loss:
# 0.00011124587564003866
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90435704]
#  [0.86809825]
#  [0.89483098]]
# Loss:
# 0.00011120742414551155
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90435952]
#  [0.86809569]
#  [0.89483137]]
# Loss:
# 0.0001111689897252824
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.904362  ]
#  [0.86809313]
#  [0.89483177]]
# Loss:
# 0.00011113057237108773
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90436448]
#  [0.86809056]
#  [0.89483216]]
# Loss:
# 0.00011109217207468717
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90436695]
#  [0.86808799]
#  [0.89483255]]
# Loss:
# 0.000111053788827875
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90436943]
#  [0.86808543]
#  [0.89483295]]
# Loss:
# 0.000111015422622473
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9043719 ]
#  [0.86808286]
#  [0.89483333]]
# Loss:
# 0.00011097707345032375
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90437437]
#  [0.86808029]
#  [0.89483372]]
# Loss:
# 0.00011093874130330154
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90437684]
#  [0.86807772]
#  [0.89483411]]
# Loss:
# 0.00011090042617330248
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90437931]
#  [0.86807515]
#  [0.8948345 ]]
# Loss:
# 0.00011086212805223971
#
#
# Input:
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
